# %%
# %run test.py
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# File /app/src/model/test.py:10
#       6 pipe.to("cuda")
#       8 image = load_image("0.jpg")
# ---> 10 image = pipe(image, "Draw me a GUI that has a dark color pallette").images[0]
#
# File /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# ...

# %%
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1080x1920>
